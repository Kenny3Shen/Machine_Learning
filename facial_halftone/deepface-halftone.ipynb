# %%
# !pip install deepface
# !pip install sklearn
# Out:
# Collecting deepface
#   Downloading deepface-0.0.79-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14.0 in /opt/conda/lib/python3.10/site-packages (from deepface) (1.23.5)
# Requirement already satisfied: pandas>=0.23.4 in /opt/conda/lib/python3.10/site-packages (from deepface) (2.0.3)
# Requirement already satisfied: tqdm>=4.30.0 in /opt/conda/lib/python3.10/site-packages (from deepface) (4.66.1)
# Collecting gdown>=3.10.1 (from deepface)
#   Downloading gdown-4.7.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /opt/conda/lib/python3.10/site-packages (from deepface) (9.5.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in /opt/conda/lib/python3.10/site-packages (from deepface) (4.8.0.76)
# Requirement already satisfied: tensorflow>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from deepface) (2.12.0)
# Requirement already satisfied: keras>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from deepface) (2.12.0)
# Requirement already satisfied: Flask>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from deepface) (2.3.3)
# Collecting mtcnn>=0.1.0 (from deepface)
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 46.5 MB/s eta 0:00:00
# Collecting retina-face>=0.0.1 (from deepface)
#   Downloading retina_face-0.0.13-py3-none-any.whl (16 kB)
# Collecting fire>=0.4.0 (from deepface)
#   Downloading fire-0.5.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 6.3 MB/s eta 0:00:00
# done
# Collecting gunicorn>=20.1.0 (from deepface)
#   Downloading gunicorn-21.2.0-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.10/site-packages (from fire>=0.4.0->deepface) (2.3.0)
# Requirement already satisfied: Werkzeug>=2.3.7 in /opt/conda/lib/python3.10/site-packages (from Flask>=1.1.2->deepface) (2.3.7)
# Requirement already satisfied: Jinja2>=3.1.2 in /opt/conda/lib/python3.10/site-packages (from Flask>=1.1.2->deepface) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/conda/lib/python3.10/site-packages (from Flask>=1.1.2->deepface) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in /opt/conda/lib/python3.10/site-packages (from Flask>=1.1.2->deepface) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /opt/conda/lib/python3.10/site-packages (from Flask>=1.1.2->deepface) (1.6.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown>=3.10.1->deepface) (3.12.2)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.10/site-packages (from gdown>=3.10.1->deepface) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown>=3.10.1->deepface) (4.12.2)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from gunicorn>=20.1.0->deepface) (21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.23.4->deepface) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=0.23.4->deepface) (2023.3)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (1.51.3)
# Requirement already satisfied: h5py>=2.9.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (3.9.0)
# Requirement already satisfied: jax>=0.3.15 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (0.4.13)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (3.20.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (68.0.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (2.12.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (4.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=1.9.0->deepface) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from jax>=0.3.15->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /opt/conda/lib/python3.10/site-packages (from jax>=0.3.15->tensorflow>=1.9.0->deepface) (1.11.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from Jinja2>=3.1.2->Flask>=1.1.2->deepface) (2.1.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (2.20.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (0.7.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.3.2.post1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->gunicorn>=20.1.0->deepface) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown>=3.10.1->deepface) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown>=3.10.1->deepface) (2023.7.22)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (0.2.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow>=1.9.0->deepface) (3.2.2)
# Building wheels for collected packages: fire
# done
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116932 sha256=bd430c3edea85498fe15df49e37eaeb7fb5cb6aaf48a97ebcc118a3fe48d9446
#   Stored in directory: /root/.cache/pip/wheels/90/d4/f7/9404e5db0116bd4d43e5666eaa3e70ab53723e1e3ea40c9a95
# Successfully built fire
# Installing collected packages: fire, mtcnn, gunicorn, gdown, retina-face, deepface
# Successfully installed deepface-0.0.79 fire-0.5.0 gdown-4.7.1 gunicorn-21.2.0 mtcnn-0.1.1 retina-face-0.0.13
# Collecting sklearn
#   Downloading sklearn-0.0.post9.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sklearn
# done
#   Created wheel for sklearn: filename=sklearn-0.0.post9-py3-none-any.whl size=2952 sha256=41153d01cf61233283f52ca7a5aa928d5ae3eab701fdee1f4099e4200f3999e3
#   Stored in directory: /root/.cache/pip/wheels/33/a3/d2/092b519e9522b4c91608b7dcec0dd9051fa1bff4c45f4502d1
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0.post9

# %%
import tarfile
tar = tarfile.open("/kaggle/input/lfwpeople/lfw-funneled.tgz")
tar.extractall("/kaggle/working")
tar.close()

# %%
import os
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import numpy as np
import pandas as pd
from deepface import DeepFace
import PIL.Image as Image


def get_dataset():
    """
    t[0]: name
    t[1]: database image
    t[2]: same person image | different person name
    if t[2] == different person name that t[3] = different person image
    :return:
    """
    # 按行读取 pairsDevTrain.txt
    test_dataset = []
    with open("/kaggle/input/lfwpeople/pairsDevTest.txt", "r") as f:
        lines = f.readlines()
        lines.pop(0)
        for line in lines:
            t = line.split("\t")
            t[-1] = t[-1].removesuffix("\n")
            test_dataset.append(t)
    return test_dataset


def verify_test_dataset(dataset, model_name="VGG-Face", distance_metric="cosine",
                        detector_backend="opencv"):
    actuals = []
    predictions = []
    predictions_halftone = []
    if not os.path.exists(f"/kaggle/working/{model_name}_{distance_metric}_{detector_backend}.csv"):
        with open(f"/kaggle/working/{model_name}_{distance_metric}_{detector_backend}.csv", "w") as f:
            f.write("1st person,2nd person,dist,verified,dist_halftone,verified_halftone\n")

    for img in dataset:
        same = True if len(img) == 3 else False
        first_img = f"/kaggle/input/label-face-in-wild/lfw/{img[0]}/{img[0]}_{int(img[1]):04d}.jpg"
        second_img = f"/kaggle/input/label-face-in-wild/lfw/{img[0]}/{img[0]}_{int(img[2]):04d}.jpg" \
            if same else f"/kaggle/input/label-face-in-wild/lfw/{img[2]}/{img[2]}_{int(img[3]):04d}.jpg"
        
        second_img_halftone = np.array(Image.open(second_img).convert("1").convert("RGB"))
        first_img = np.array(Image.open(first_img))
        second_img = np.array(Image.open(second_img))
        # opencv expects bgr instead of rgb
        first_img = first_img[:, :, ::-1]
        second_img = second_img[:, :, ::-1]
        second_img_halftone = second_img_halftone[:, :, ::-1]
        
        result = DeepFace.verify(first_img, second_img, model_name=model_name, distance_metric=distance_metric,
                                 detector_backend=detector_backend, enforce_detection=False)
        result_halftone = DeepFace.verify(first_img, second_img_halftone, model_name=model_name,
                                          distance_metric=distance_metric,
                                          detector_backend=detector_backend, enforce_detection=False)

        data = pd.DataFrame({"1st person": [img[0]],
                             "2nd person": [img[0] if same else img[2]],
                             "dist": [result["distance"]],
                             "verified": [result["verified"]],
                             "dist_halftone": [result_halftone["distance"]],
                             "verified_halftone": [result_halftone["verified"]]
                             })

        data.to_csv(f"./{model_name}_{distance_metric}_{detector_backend}.csv", mode="a", header=False, index=False)

        print(f"{img} dist: {result['distance']} verified: {result['verified']} dist_halftone: {result_halftone['distance']} verified_halftone: {result_halftone['verified']}")
        actuals.append(True if same else False)
        predictions.append(result["verified"])
        predictions_halftone.append(result_halftone["verified"])

    accuracy = 100 * accuracy_score(actuals, predictions)
    precision = 100 * precision_score(actuals, predictions)
    recall = 100 * recall_score(actuals, predictions)
    f1 = 100 * f1_score(actuals, predictions)
    tn, fp, fn, tp = confusion_matrix(actuals, predictions).ravel()

    metric = pd.DataFrame({"accuracy": [accuracy],
                           "precision": [precision],
                           "recall": [recall],
                           "f1": [f1],
                           "tn": [tn],
                           "fp": [fp],
                           "fn": [fn],
                           "tp": [tp]
                           })
    metric.to_csv(f"/kaggle/working/{model_name}_{distance_metric}_{detector_backend}.csv", mode="a", header=True, index=False)

    accuracy_halftone = 100 * accuracy_score(actuals, predictions_halftone)
    precision_halftone = 100 * precision_score(actuals, predictions_halftone)
    recall_halftone = 100 * recall_score(actuals, predictions_halftone)
    f1_halftone = 100 * f1_score(actuals, predictions_halftone)
    tn_halftone, fp_halftone, fn_halftone, tp_halftone = confusion_matrix(actuals, predictions_halftone).ravel()
    metric_halftone = pd.DataFrame({"h_accuracy": [accuracy_halftone],
                                    "h_precision": [precision_halftone],
                                    "h_recall": [recall_halftone],
                                    "h_f1": [f1_halftone],
                                    "h_tn": [tn_halftone],
                                    "h_fp": [fp_halftone],
                                    "h_fn": [fn_halftone],
                                    "h_tp": [tp_halftone]
                                    })
    metric_halftone.to_csv(f"/kaggle/working/{model_name}_{distance_metric}_{detector_backend}.csv", mode="a", header=True,
                           index=False)


# Euclidean L2 form seems to be more stable than cosine and regular Euclidean distance based on experiments.

# Face recognition models are actually CNN models and they expect standard sized inputs. So, resizing is required before
# representation. To avoid deformation, deepface adds black padding pixels according to the target size argument
# after detection and alignment.

# RetinaFace and MTCNN seem to over-perform in detection and alignment stages, but they
# are much slower. If the speed of your pipeline is more important, then you should use opencv or ssd. On the other
# hand, if you consider the accuracy, then you should use retinaface or mtcnn.
if __name__ == '__main__':
    models = [
        "VGG-Face",
        "Facenet",
        "Facenet512",
        "OpenFace",
        "DeepFace",
        "DeepID",
        "ArcFace",
        "Dlib",
        "SFace",
    ]
    backends = [
        'opencv',
        'ssd',
        'dlib',
        'mtcnn',
        'retinaface',
        'mediapipe',
        'yolov8',
        'yunet',
    ]
    metrics = ["cosine", "euclidean", "euclidean_l2"]
    dataset = get_dataset()
    # t = dataset[0]
    # res = df.verify(f"./lfw_funneled/{t[0]}/{t[0]}_{int(t[1]):04d}.jpg",
    #                 f"./lfw_funneled/{t[0]}/{t[0]}_{int(t[2]):04d}.jpg",
    #                 model_name="VGG-Face", distance_metric="cosine", detector_backend="opencv")
    # print(res)
    # facenet proved to not be a good model for halftone face recognition
    verify_test_dataset(dataset, model_name=models[0], distance_metric=metrics[1], detector_backend=backends[0])
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created
# vgg_face_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/vgg_face_weights.h5
# To: /root/.deepface/weights/vgg_face_weights.h5
# 100%|██████████| 580M/580M [00:01<00:00, 345MB/s]
# ['Abdullah_Gul', '13', '14'] dist: 0.28609922423450596 verified: True dist_halftone: 0.5131605209078882 verified_halftone: True
# ['Abdullah_Gul', '13', '16'] dist: 0.4345321888148093 verified: True dist_halftone: 0.5546657021248516 verified_halftone: True
# ['Abdullatif_Sener', '1', '2'] dist: 0.3067683281298301 verified: True dist_halftone: 0.38523682870757747 verified_halftone: True
# ['Adel_Al-Jubeir', '1', '3'] dist: 0.2499771257449424 verified: True dist_halftone: 0.36364087688287594 verified_halftone: True
# ['Al_Pacino', '1', '2'] dist: 0.32166355863823853 verified: True dist_halftone: 0.6172695968599591 verified_halftone: False
# ['Alan_Greenspan', '1', '5'] dist: 0.2777969849081003 verified: True dist_halftone: 0.46188376755087374 verified_halftone: True
# ['Albert_Costa', '2', '6'] dist: 0.44441636124867334 verified: True dist_halftone: 0.598045648285905 verified_halftone: True
# ['Albert_Costa', '4', '6'] dist: 0.4787032721470334 verified: True dist_halftone: 0.607291684108223 verified_halftone: False
# ['Albert_Costa', '5', '6'] dist: 0.45020219903107855 verified: True dist_halftone: 0.5804776036661103 verified_halftone: True
# ['Alejandro_Atchugarry', '1', '2'] dist: 0.4159892623390141 verified: True dist_halftone: 0.6282230230480796 verified_halftone: False
# ['Alex_Penelas', '1', '2'] dist: 0.3682805216760219 verified: True dist_halftone: 0.45644058890027445 verified_halftone: True
# ['Ali_Naimi', '1', '3'] dist: 0.23114480245941882 verified: True dist_halftone: 0.5393184074315353 verified_halftone: True
# ['Ali_Naimi', '3', '4'] dist: 0.3598996936232098 verified: True dist_halftone: 0.6087977671173938 verified_halftone: False
# ['Allison_Janney', '1', '2'] dist: 0.5255300816262947 verified: True dist_halftone: 0.721093216522549 verified_halftone: False
# ['Allyson_Felix', '2', '5'] dist: 0.3929462773435892 verified: True dist_halftone: 0.44752257401850154 verified_halftone: True
# ['Alvaro_Uribe', '7', '10'] dist: 0.27494968631518996 verified: True dist_halftone: 0.33830236970977356 verified_halftone: True
# ['Alvaro_Uribe', '17', '26'] dist: 0.2740223266576024 verified: True dist_halftone: 0.3974744780391077 verified_halftone: True
# ['Alvaro_Uribe', '28', '29'] dist: 0.5191849950325952 verified: True dist_halftone: 0.5316723427454263 verified_halftone: True
# ['Amanda_Bynes', '1', '2'] dist: 0.48607763273205745 verified: True dist_halftone: 0.6796272229036309 verified_halftone: False
# ['Amanda_Bynes', '1', '3'] dist: 0.5453492641099865 verified: True dist_halftone: 0.7475236381209878 verified_halftone: False
# ['Amanda_Bynes', '1', '4'] dist: 0.6532069501124299 verified: False dist_halftone: 0.7267568280220258 verified_halftone: False
# ['Amanda_Bynes', '3', '4'] dist: 0.4379342220563555 verified: True dist_halftone: 0.5876733789158615 verified_halftone: True
# ['Amelie_Mauresmo', '1', '21'] dist: 0.647266654107252 verified: False dist_halftone: 0.6806967527367155 verified_halftone: False
# ['Amelie_Mauresmo', '4', '11'] dist: 0.42252706956574726 verified: True dist_halftone: 0.6450154348378999 verified_halftone: False
# ['Amelie_Mauresmo', '16', '21'] dist: 0.6986223301642696 verified: False dist_halftone: 0.7179868822539486 verified_halftone: False
# ['Ana_Palacio', '1', '6'] dist: 0.348082808688402 verified: True dist_halftone: 0.5669521927958335 verified_halftone: True
# ['Andrei_Mikhnevich', '1', '2'] dist: 0.34527261431839773 verified: True dist_halftone: 0.4915812722699611 verified_halftone: True
# ['Andy_Hebb', '1', '2'] dist: 0.3863877979747049 verified: True dist_halftone: 0.46414120433089767 verified_halftone: True
# ['Angelo_Reyes', '1', '2'] dist: 0.1973967700037043 verified: True dist_halftone: 0.3658289827061537 verified_halftone: True
# ['Angelo_Reyes', '2', '3'] dist: 0.3172900515332609 verified: True dist_halftone: 0.45667362733866845 verified_halftone: True
# ['Ann_Veneman', '1', '2'] dist: 0.40691174192647955 verified: True dist_halftone: 0.45832139477610084 verified_halftone: True
# ['Ann_Veneman', '5', '11'] dist: 0.43642238219954155 verified: True dist_halftone: 0.5948740815913331 verified_halftone: True
# ['Ann_Veneman', '8', '9'] dist: 0.37306625267107596 verified: True dist_halftone: 0.5784284596388003 verified_halftone: True
# ['Anna_Nicole_Smith', '1', '2'] dist: 0.5988039619118323 verified: True dist_halftone: 0.6781719253081697 verified_halftone: False
# ['Anne_Krueger', '1', '2'] dist: 0.525751032230631 verified: True dist_halftone: 0.41426423246197697 verified_halftone: True
# ['Anne_Krueger', '2', '3'] dist: 0.5387442413079128 verified: True dist_halftone: 0.6446816954977381 verified_halftone: False
# ['Annette_Lu', '1', '2'] dist: 0.338745058673757 verified: True dist_halftone: 0.36416640807237055 verified_halftone: True
# ['Annette_Lu', '1', '3'] dist: 0.3740398676095313 verified: True dist_halftone: 0.3302854173269469 verified_halftone: True
# ['Annette_Lu', '2', '3'] dist: 0.33132720628589307 verified: True dist_halftone: 0.3797656064482952 verified_halftone: True
# ['Antonio_Palocci', '3', '8'] dist: 0.23638051599846194 verified: True dist_halftone: 0.36468927995312894 verified_halftone: True
# ['Antonio_Trillanes', '1', '2'] dist: 0.2809860586228925 verified: True dist_halftone: 0.40123662781223546 verified_halftone: True
# ['Antonio_Trillanes', '2', '3'] dist: 0.4666683364323908 verified: True dist_halftone: 0.6298319215447742 verified_halftone: False
# ['Arlen_Specter', '1', '3'] dist: 0.46594288405442663 verified: True dist_halftone: 0.5197146805869534 verified_halftone: True
# ['Augustin_Calleri', '1', '3'] dist: 0.43373647925794945 verified: True dist_halftone: 0.5400809818551814 verified_halftone: True
# ['Augustin_Calleri', '1', '4'] dist: 0.574697108106398 verified: True dist_halftone: 0.5034024943452282 verified_halftone: True
# ['Barbara_Brezigar', '1', '2'] dist: 0.6597535439186221 verified: False dist_halftone: 0.6876463436450168 verified_halftone: False
# ['Begum_Khaleda_Zia', '1', '2'] dist: 0.3143051600016191 verified: True dist_halftone: 0.4840086988734446 verified_halftone: True
# ['Ben_Affleck', '1', '3'] dist: 0.32037403237694134 verified: True dist_halftone: 0.4974166277396409 verified_halftone: True
# ['Ben_Affleck', '2', '6'] dist: 0.3735167159732227 verified: True dist_halftone: 0.5274859599611725 verified_halftone: True
# ['Ben_Affleck', '3', '6'] dist: 0.37547574422405744 verified: True dist_halftone: 0.5267948526706535 verified_halftone: True
# ['Bertie_Ahern', '2', '3'] dist: 0.28501320439954764 verified: True dist_halftone: 0.4924375055162457 verified_halftone: True
# ['Bill_Frist', '1', '3'] dist: 0.504934490337076 verified: True dist_halftone: 0.7445754310997756 verified_halftone: False
# ['Bill_Frist', '2', '7'] dist: 0.4512233603930231 verified: True dist_halftone: 0.6171366465998588 verified_halftone: False
# ['Bill_Frist', '3', '8'] dist: 0.5405067693069224 verified: True dist_halftone: 0.5270749964330077 verified_halftone: True
# ['Bill_McBride', '2', '6'] dist: 0.3946034287044233 verified: True dist_halftone: 0.46782170879397206 verified_halftone: True
# ['Bill_McBride', '2', '10'] dist: 0.43821959255228426 verified: True dist_halftone: 0.45616141360725726 verified_halftone: True
# ['Bill_McBride', '3', '9'] dist: 0.35094677715104317 verified: True dist_halftone: 0.5126459138122005 verified_halftone: True
# ['Bill_Sizemore', '1', '2'] dist: 0.28801100943170044 verified: True dist_halftone: 0.4337077137550449 verified_halftone: True
# ['Bono', '1', '2'] dist: 0.5342078716909178 verified: True dist_halftone: 0.6035094088127914 verified_halftone: False
# ['Bono', '1', '3'] dist: 0.5833635793032288 verified: True dist_halftone: 0.6633532030751079 verified_halftone: False
# ['Bono', '2', '3'] dist: 0.49585246540109346 verified: True dist_halftone: 0.5945098777407503 verified_halftone: True
# ['Brian_Cowen', '1', '2'] dist: 0.41390758605689854 verified: True dist_halftone: 0.41522696150036187 verified_halftone: True
# ['Bridget_Fonda', '1', '3'] dist: 0.39655965868151827 verified: True dist_halftone: 0.5739531629342262 verified_halftone: True
# ['Bridgette_Wilson-Sampras', '1', '2'] dist: 0.7971248821322856 verified: False dist_halftone: 0.7950185146864938 verified_halftone: False
# ['Butch_Davis', '1', '2'] dist: 0.47761334069997224 verified: True dist_halftone: 0.555113126926669 verified_halftone: True
# ['Calista_Flockhart', '2', '6'] dist: 0.5204849996278459 verified: True dist_halftone: 0.6808454516358086 verified_halftone: False
# ['Candice_Bergen', '1', '3'] dist: 0.5382146656857975 verified: True dist_halftone: 0.6188669910384934 verified_halftone: False
# ['Carla_Del_Ponte', '2', '4'] dist: 0.3703247403610248 verified: True dist_halftone: 0.5975885121656725 verified_halftone: True
# ['Carla_Del_Ponte', '4', '5'] dist: 0.4177057099930316 verified: True dist_halftone: 0.4278596188375673 verified_halftone: True
# ['Carlos_Manuel_Pruneda', '1', '2'] dist: 0.5008907591217505 verified: True dist_halftone: 0.47517946593284 verified_halftone: True
# ['Carlos_Manuel_Pruneda', '1', '3'] dist: 0.5080496354640198 verified: True dist_halftone: 0.5416266847978457 verified_halftone: True
# ['Carlos_Manuel_Pruneda', '2', '3'] dist: 0.4947468468636075 verified: True dist_halftone: 0.4860103657135732 verified_halftone: True
# ['Carlos_Moya', '7', '11'] dist: 0.5223119297610431 verified: True dist_halftone: 0.592313038884852 verified_halftone: True
# ['Carlos_Ortega', '1', '3'] dist: 0.37230423658341827 verified: True dist_halftone: 0.4918874194198685 verified_halftone: True
# ['Carolyn_Dawn_Johnson', '2', '3'] dist: 0.6502106514504004 verified: False dist_halftone: 0.607544755752452 verified_halftone: False
# ['Carrie-Anne_Moss', '2', '5'] dist: 0.6117204045450079 verified: False dist_halftone: 0.6780392698131429 verified_halftone: False
# ['Carson_Daly', '1', '2'] dist: 0.5114192598076978 verified: True dist_halftone: 0.5207739599114527 verified_halftone: True
# ['Cathy_Freeman', '1', '2'] dist: 0.2708722510880463 verified: True dist_halftone: 0.4111480148597416 verified_halftone: True
# ['Chanda_Rubin', '2', '4'] dist: 0.3999536329680328 verified: True dist_halftone: 0.5522715901642921 verified_halftone: True
# ['Chang_Dae-whan', '1', '2'] dist: 0.34336407370938893 verified: True dist_halftone: 0.39281911273879 verified_halftone: True
# ['Charles_Taylor', '3', '9'] dist: 0.4719574950999022 verified: True dist_halftone: 0.5273042485871438 verified_halftone: True
# ['Chen_Shui-bian', '3', '5'] dist: 0.434712923761548 verified: True dist_halftone: 0.577515338173557 verified_halftone: True
# ['Chita_Rivera', '1', '2'] dist: 0.338975759406728 verified: True dist_halftone: 0.6040353962160145 verified_halftone: False
# ['Chok_Tong_Goh', '1', '2'] dist: 0.5364534535790108 verified: True dist_halftone: 0.5620728237130235 verified_halftone: True
# ['Chris_Bell', '1', '2'] dist: 0.3159729383848922 verified: True dist_halftone: 0.5575471325901641 verified_halftone: True
# ['Chris_Byrd', '1', '2'] dist: 0.39632011403071327 verified: True dist_halftone: 0.49968293496222727 verified_halftone: True
# ['Christian_Longo', '1', '3'] dist: 0.2831731152016663 verified: True dist_halftone: 0.4395959440956723 verified_halftone: True
# ['Christian_Longo', '2', '3'] dist: 0.3665419711678012 verified: True dist_halftone: 0.4333594185632975 verified_halftone: True
# ['Christian_Wulff', '1', '2'] dist: 0.4503571435398639 verified: True dist_halftone: 0.5330327171324998 verified_halftone: True
# ['Christine_Ebersole', '1', '2'] dist: 0.7125976206000301 verified: False dist_halftone: 0.7017659704785855 verified_halftone: False
# ['Christine_Todd_Whitman', '5', '6'] dist: 0.505161778320101 verified: True dist_halftone: 0.5893984938252858 verified_halftone: True
# ['Christopher_Reeve', '1', '4'] dist: 0.4590357492221794 verified: True dist_halftone: 0.6115870751362459 verified_halftone: False
# ['Claire_Leger', '1', '2'] dist: 0.3661630247374354 verified: True dist_halftone: 0.4164160658476007 verified_halftone: True
# ['Condoleezza_Rice', '2', '5'] dist: 0.3659349677030626 verified: True dist_halftone: 0.6116594375664175 verified_halftone: False
# ['Condoleezza_Rice', '7', '10'] dist: 0.2659958601954669 verified: True dist_halftone: 0.39637569205139617 verified_halftone: True
# ['Cristina_Fernandez', '1', '2'] dist: 0.7248502158993253 verified: False dist_halftone: 0.5959044150106673 verified_halftone: True
# ['Dai_Bachtiar', '1', '2'] dist: 0.3895407557631652 verified: True dist_halftone: 0.4137345091040399 verified_halftone: True
# ['Daisy_Fuentes', '3', '4'] dist: 0.5525096101094878 verified: True dist_halftone: 0.5813193175382712 verified_halftone: True
# ['Dave_Campo', '1', '2'] dist: 0.5331381696273012 verified: True dist_halftone: 0.6390471849759237 verified_halftone: False
# ['Dave_Campo', '2', '3'] dist: 0.5155756254625423 verified: True dist_halftone: 0.5479947824055906 verified_halftone: True
# ['David_Stern', '1', '4'] dist: 0.4200706151071505 verified: True dist_halftone: 0.5417387010234921 verified_halftone: True
# ['David_Stern', '3', '4'] dist: 0.42678259577919336 verified: True dist_halftone: 0.49954127866298176 verified_halftone: True
# ['Denise_Johnson', '1', '2'] dist: 0.544844752761259 verified: True dist_halftone: 0.5662046862445947 verified_halftone: True
# ['Dennis_Powell', '1', '2'] dist: 0.34131293975042 verified: True dist_halftone: 0.4363093290994549 verified_halftone: True
# ['Denzel_Washington', '1', '3'] dist: 0.21434539264159228 verified: True dist_halftone: 0.5872721960901504 verified_halftone: True
# ['Denzel_Washington', '2', '4'] dist: 0.3490101262843571 verified: True dist_halftone: 0.8018012091311952 verified_halftone: False
# ['Denzel_Washington', '2', '5'] dist: 0.41167668213374836 verified: True dist_halftone: 0.5700508032391213 verified_halftone: True
# ['Derek_Jeter', '2', '3'] dist: 0.4087985430626985 verified: True dist_halftone: 0.5761117047078436 verified_halftone: True
# ['Diane_Green', '1', '2'] dist: 0.3647220751383131 verified: True dist_halftone: 0.5429066722098038 verified_halftone: True
# ['Dick_Clark', '1', '2'] dist: 0.3680474503830162 verified: True dist_halftone: 0.4974735840946698 verified_halftone: True
# ['Dick_Clark', '1', '3'] dist: 0.3423032045135561 verified: True dist_halftone: 0.4743836157868384 verified_halftone: True
# ['Dick_Clark', '2', '3'] dist: 0.4127234030500327 verified: True dist_halftone: 0.5262276588240238 verified_halftone: True
# ['Dick_Vermeil', '1', '2'] dist: 0.5060176565607112 verified: True dist_halftone: 0.46665122846781415 verified_halftone: True
# ['Dominique_de_Villepin', '3', '5'] dist: 0.4499304016910188 verified: True dist_halftone: 0.5013428612101801 verified_halftone: True
# ['Dominique_de_Villepin', '7', '11'] dist: 0.424887653009944 verified: True dist_halftone: 0.47784574976216243 verified_halftone: True
# ['Dominique_de_Villepin', '14', '15'] dist: 0.31308970215328163 verified: True dist_halftone: 0.5333284113255657 verified_halftone: True
# ['Donald_Pettit', '1', '2'] dist: 0.35394750076610226 verified: True dist_halftone: 0.48842912363202573 verified_halftone: True
# ['Donald_Pettit', '2', '3'] dist: 0.37739541948853167 verified: True dist_halftone: 0.4958453804788679 verified_halftone: True
# ['Donald_Rumsfeld', '22', '36'] dist: 0.34252435320732594 verified: True dist_halftone: 0.4638507595361165 verified_halftone: True
# ['Donald_Rumsfeld', '28', '108'] dist: 0.3867974042157266 verified: True dist_halftone: 0.6286549998279468 verified_halftone: False
# ['Donald_Rumsfeld', '41', '48'] dist: 0.40166160521834526 verified: True dist_halftone: 0.5522069775235146 verified_halftone: True
# ['Doug_Collins', '1', '2'] dist: 0.3221482407856255 verified: True dist_halftone: 0.3917733794140212 verified_halftone: True
# ['Edward_Lu', '2', '4'] dist: 0.3781654039578064 verified: True dist_halftone: 0.4262040950220486 verified_halftone: True
# ['Edward_Norton', '1', '2'] dist: 0.457059487824278 verified: True dist_halftone: 0.4630551138313754 verified_halftone: True
# ['Edwin_Edwards', '1', '2'] dist: 0.3869964533507832 verified: True dist_halftone: 0.6419370011802585 verified_halftone: False
# ['Edwin_Edwards', '2', '3'] dist: 0.4176381055875318 verified: True dist_halftone: 0.4573416511002083 verified_halftone: True
# ['Eliane_Karp', '1', '4'] dist: 0.7066226620008091 verified: False dist_halftone: 0.68384354770251 verified_halftone: False
# ['Eliane_Karp', '2', '3'] dist: 0.6276437194901832 verified: False dist_halftone: 0.7859698967715524 verified_halftone: False
# ['Elin_Nordegren', '1', '2'] dist: 0.6435598093244689 verified: False dist_halftone: 0.7272357905105241 verified_halftone: False
# ['Elinor_Caplan', '1', '2'] dist: 0.6092728750693799 verified: False dist_halftone: 0.6122749645433264 verified_halftone: False
# ['Elisabeth_Schumacher', '1', '2'] dist: 0.6306892903854086 verified: False dist_halftone: 0.5315733005578049 verified_halftone: True
# ['Elizabeth_Smart', '1', '5'] dist: 0.4727203979275511 verified: True dist_halftone: 0.7362791082853443 verified_halftone: False
# ['Elizabeth_Smart', '3', '4'] dist: 0.49979200684532205 verified: True dist_halftone: 0.5992513208649809 verified_halftone: True
# ['Elsa_Zylberstein', '1', '2'] dist: 0.5933613769921537 verified: True dist_halftone: 0.5727584610600593 verified_halftone: True
# ['Elsa_Zylberstein', '1', '5'] dist: 0.4586761063558834 verified: True dist_halftone: 0.4746503734991557 verified_halftone: True
# ['Elsa_Zylberstein', '3', '6'] dist: 0.3877563562097971 verified: True dist_halftone: 0.7040128838586092 verified_halftone: False
# ['Emma_Watson', '1', '4'] dist: 0.4135207752133876 verified: True dist_halftone: 0.6554207524520967 verified_halftone: False
# ['Emma_Watson', '2', '3'] dist: 0.4391256326390642 verified: True dist_halftone: 0.49648066434668064 verified_halftone: True
# ['Emma_Watson', '3', '5'] dist: 0.43793591232967516 verified: True dist_halftone: 0.6366341097716763 verified_halftone: False
# ['Erik_Morales', '1', '3'] dist: 0.4468316587135003 verified: True dist_halftone: 0.5570299855147516 verified_halftone: True
# ['Erika_Christensen', '1', '2'] dist: 0.46563602631964307 verified: True dist_halftone: 0.6498485953262334 verified_halftone: False
# ['Erin_Runnion', '3', '4'] dist: 0.5259943035358912 verified: True dist_halftone: 0.6108035779562508 verified_halftone: False
# ['Ernie_Fletcher', '1', '2'] dist: 0.36830425921077975 verified: True dist_halftone: 0.4033775273869337 verified_halftone: True
# ['Fabiola_Zuluaga', '1', '2'] dist: 0.5248765414219086 verified: True dist_halftone: 0.581588751376277 verified_halftone: True
# ['Felipe_Perez_Roque', '1', '4'] dist: 0.29303922061183046 verified: True dist_halftone: 0.41094555006367556 verified_halftone: True
# ['Felipe_Perez_Roque', '2', '4'] dist: 0.28773134306352505 verified: True dist_halftone: 0.35755687397087843 verified_halftone: True
# ['Fernando_Vargas', '2', '4'] dist: 0.4017415050841947 verified: True dist_halftone: 0.40542639763411603 verified_halftone: True
# ['Flor_Montulo', '1', '2'] dist: 0.4899207047328227 verified: True dist_halftone: 0.4537803958935387 verified_halftone: True
# ['Frank_Cassell', '1', '2'] dist: 0.3551541503578148 verified: True dist_halftone: 0.3703590316759574 verified_halftone: True
# ['Frank_Dunham_Jr', '1', '2'] dist: 0.35966252976816093 verified: True dist_halftone: 0.5368984751490057 verified_halftone: True
# ['Gao_Qiang', '1', '2'] dist: 0.4789475095514137 verified: True dist_halftone: 0.5731053637878186 verified_halftone: True
# ['Garry_Trudeau', '1', '2'] dist: 0.373305400986217 verified: True dist_halftone: 0.46711394938890727 verified_halftone: True
# ['Gary_Doer', '1', '2'] dist: 0.36418851995821666 verified: True dist_halftone: 0.46198317564737335 verified_halftone: True
# ['Gary_Doer', '1', '3'] dist: 0.3316852282435756 verified: True dist_halftone: 0.44871818210200193 verified_halftone: True
# ['Gary_Doer', '2', '3'] dist: 0.3887720617903786 verified: True dist_halftone: 0.5219627212687407 verified_halftone: True
# ['Gary_Winnick', '1', '2'] dist: 0.4287208202717366 verified: True dist_halftone: 0.5814573060011831 verified_halftone: True
# ['Gene_Robinson', '2', '4'] dist: 0.27303664486382284 verified: True dist_halftone: 0.3568576283020263 verified_halftone: True
# ['George_Foreman', '1', '2'] dist: 0.3641442085259617 verified: True dist_halftone: 0.6089656250369896 verified_halftone: False
# ['George_Karl', '1', '2'] dist: 0.37053815896885506 verified: True dist_halftone: 0.43179932380469127 verified_halftone: True
# ['George_Robertson', '5', '20'] dist: 0.321176741022207 verified: True dist_halftone: 0.35408082414101855 verified_halftone: True
# ['George_Robertson', '12', '19'] dist: 0.22621854206099684 verified: True dist_halftone: 0.38113417143503553 verified_halftone: True
# ['George_Robertson', '15', '22'] dist: 0.44586663225301637 verified: True dist_halftone: 0.5373080729550068 verified_halftone: True
# ['Georgi_Parvanov', '1', '2'] dist: 0.43425744181970605 verified: True dist_halftone: 0.7440658222640916 verified_halftone: False
# ['Geraldine_Chaplin', '1', '3'] dist: 0.31338307470254484 verified: True dist_halftone: 0.5919870314178911 verified_halftone: True
# ['Gerhard_Schroeder', '3', '26'] dist: 0.30840341118890235 verified: True dist_halftone: 0.3593103029214246 verified_halftone: True
# ['Gerry_Adams', '3', '7'] dist: 0.4926547331493784 verified: True dist_halftone: 0.573371887335805 verified_halftone: True
# ['Gerry_Adams', '5', '8'] dist: 0.4850575594426532 verified: True dist_halftone: 0.5170627881662768 verified_halftone: True
# ['Gilberto_Rodriguez_Orejuela', '1', '3'] dist: 0.31804178245027276 verified: True dist_halftone: 0.48787427739520817 verified_halftone: True
# ['Gilberto_Rodriguez_Orejuela', '2', '4'] dist: 0.4381307306579969 verified: True dist_halftone: 0.5597654544463186 verified_halftone: True
# ['Gilberto_Rodriguez_Orejuela', '3', '4'] dist: 0.34755297274249897 verified: True dist_halftone: 0.5042578681722881 verified_halftone: True
# ['Giuseppe_Gibilisco', '2', '4'] dist: 0.35661910050038803 verified: True dist_halftone: 0.3582014987894165 verified_halftone: True
# ['Giuseppe_Gibilisco', '3', '4'] dist: 0.4549026833066707 verified: True dist_halftone: 0.4741530839655083 verified_halftone: True
# ['Glafcos_Clerides', '1', '4'] dist: 0.40330670554826165 verified: True dist_halftone: 0.5195857239786335 verified_halftone: True
# ['Gordon_Brown', '4', '11'] dist: 0.6528877477092012 verified: False dist_halftone: 0.5450939435027768 verified_halftone: True
# ['Gordon_Campbell', '1', '2'] dist: 0.2937438871532082 verified: True dist_halftone: 0.41085602564222706 verified_halftone: True
# ['Gray_Davis', '6', '23'] dist: 0.31959669787876166 verified: True dist_halftone: 0.6569803653864389 verified_halftone: False
# ['Gray_Davis', '13', '23'] dist: 0.332764696529131 verified: True dist_halftone: 0.6302151878198106 verified_halftone: False
# ['Greg_Gilbert', '1', '2'] dist: 0.4012314673271688 verified: True dist_halftone: 0.5674013784141954 verified_halftone: True
# ['Greg_Ostertag', '1', '2'] dist: 0.4364478153235789 verified: True dist_halftone: 0.4155922997018973 verified_halftone: True
# ['Gregory_Hines', '1', '2'] dist: 0.3072318420500329 verified: True dist_halftone: 0.3605192843612693 verified_halftone: True
# ['Gus_Van_Sant', '1', '2'] dist: 0.32103151557707515 verified: True dist_halftone: 0.533245446689645 verified_halftone: True
# ['Gwendal_Peizerat', '1', '2'] dist: 0.5043046389247673 verified: True dist_halftone: 0.6973574811243061 verified_halftone: False
# ['Gwyneth_Paltrow', '4', '5'] dist: 0.49175729629724063 verified: True dist_halftone: 0.6104892709664194 verified_halftone: False
# ['Harry_Kalas', '1', '2'] dist: 0.45105874940800383 verified: True dist_halftone: 0.5386075620257974 verified_halftone: True
# ['Hassan_Wirajuda', '1', '2'] dist: 0.30972872664376494 verified: True dist_halftone: 0.4560381424877835 verified_halftone: True
# ['Heather_Mills', '3', '4'] dist: 0.5342251271810884 verified: True dist_halftone: 0.6212303334112924 verified_halftone: False
# ['Heidi_Fleiss', '1', '3'] dist: 0.49359012651954304 verified: True dist_halftone: 0.6807119911587413 verified_halftone: False
# ['Heidi_Fleiss', '1', '4'] dist: 0.6463721653461486 verified: False dist_halftone: 0.721585158234066 verified_halftone: False
# ['Hermann_Maier', '1', '2'] dist: 0.5545594642561803 verified: True dist_halftone: 0.5813663916469436 verified_halftone: True
# ['Horst_Koehler', '1', '3'] dist: 0.48774600016535535 verified: True dist_halftone: 0.5361997028113239 verified_halftone: True
# ['Ian_Thorpe', '2', '7'] dist: 0.4232991529842623 verified: True dist_halftone: 0.5188291152303014 verified_halftone: True
# ['Ian_Thorpe', '3', '10'] dist: 0.4717931611890577 verified: True dist_halftone: 0.8410174360463902 verified_halftone: False
# ['Ian_Thorpe', '6', '8'] dist: 0.42351139376004177 verified: True dist_halftone: 0.5670121052531485 verified_halftone: True
# ['Isabella_Rossellini', '1', '2'] dist: 0.492954815110332 verified: True dist_halftone: 0.5073704838057891 verified_halftone: True
# ['Isabelle_Huppert', '1', '2'] dist: 0.4405940848291755 verified: True dist_halftone: 0.6585044333142378 verified_halftone: False
# ['Ismail_Merchant', '1', '2'] dist: 0.3249748919242901 verified: True dist_halftone: 0.597319950237006 verified_halftone: True
# ['Jack_Grubman', '1', '2'] dist: 0.3009269419327792 verified: True dist_halftone: 0.41909547001692227 verified_halftone: True
# ['Jack_Nicholson', '2', '3'] dist: 0.42621418596939137 verified: True dist_halftone: 0.5544298301427102 verified_halftone: True
# ['Jacques_Chirac', '22', '44'] dist: 0.46606255366380706 verified: True dist_halftone: 0.6013472417314809 verified_halftone: False
# ['Jacques_Chirac', '30', '33'] dist: 0.32193939744713385 verified: True dist_halftone: 0.5254107234482851 verified_halftone: True
# ['Jacques_Chirac', '31', '52'] dist: 0.3034764036955518 verified: True dist_halftone: 0.37832351903522604 verified_halftone: True
# ['Jacques_Rogge', '4', '6'] dist: 0.2778039949164267 verified: True dist_halftone: 0.46170325477016844 verified_halftone: True
# ['Jake_Gyllenhaal', '2', '4'] dist: 0.4529336144340717 verified: True dist_halftone: 0.49148203079628694 verified_halftone: True
# ['Jake_Gyllenhaal', '3', '4'] dist: 0.3149592681067585 verified: True dist_halftone: 0.40743373869773586 verified_halftone: True
# ['James_Butts', '1', '2'] dist: 0.30543526526182424 verified: True dist_halftone: 0.3523370247490396 verified_halftone: True
# ['James_Franco', '1', '2'] dist: 0.45565856094023993 verified: True dist_halftone: 0.5296248980405973 verified_halftone: True
# ['James_Kelly', '4', '11'] dist: 0.2840701842168674 verified: True dist_halftone: 0.3631216824196847 verified_halftone: True
# ['James_Kelly', '9', '11'] dist: 0.3595031300072446 verified: True dist_halftone: 0.44408317639578565 verified_halftone: True
# ['James_Kopp', '1', '3'] dist: 0.3283186117251775 verified: True dist_halftone: 0.37468401007670554 verified_halftone: True
# ['James_Kopp', '2', '3'] dist: 0.458563721874851 verified: True dist_halftone: 0.43354260253780263 verified_halftone: True
# ['James_Maguire', '1', '2'] dist: 0.4242438921628461 verified: True dist_halftone: 0.41580801104400716 verified_halftone: True
# ['James_Smith', '1', '2'] dist: 0.2979445828054953 verified: True dist_halftone: 0.38456729548785634 verified_halftone: True
# ['Jan_Ullrich', '2', '3'] dist: 0.26375017095715825 verified: True dist_halftone: 0.6571496313510795 verified_halftone: False
# ['Jan_Ullrich', '2', '5'] dist: 0.5840514508498046 verified: True dist_halftone: 0.8351453247351076 verified_halftone: False
# ['Janica_Kostelic', '1', '2'] dist: 0.899681774904486 verified: False dist_halftone: 0.8265505876250043 verified_halftone: False
# ['Javier_Weber', '1', '2'] dist: 0.6150662249520141 verified: False dist_halftone: 0.4921254122503065 verified_halftone: True
# ['Javier_Weber', '1', '3'] dist: 0.6201691648332239 verified: False dist_halftone: 0.49875181260868195 verified_halftone: True
# ['Jean-Claude_Juncker', '1', '2'] dist: 0.3257626451361125 verified: True dist_halftone: 0.32328626820566464 verified_halftone: True
# ['Jean-Claude_Trichet', '1', '2'] dist: 0.4004127383295675 verified: True dist_halftone: 0.5173126588058694 verified_halftone: True
# ['Jean-Marc_de_La_Sabliere', '1', '2'] dist: 0.301952614339973 verified: True dist_halftone: 0.45806492458825554 verified_halftone: True
# ['Jean-Pierre_Raffarin', '2', '6'] dist: 0.43692879010990693 verified: True dist_halftone: 0.5276523791645401 verified_halftone: True
# ['Jean_Carnahan', '1', '2'] dist: 0.5333841120176589 verified: True dist_halftone: 0.5738633307901612 verified_halftone: True
# ['Jefferson_Perez', '1', '2'] dist: 0.5381599311156654 verified: True dist_halftone: 0.6155767542508978 verified_halftone: False
# ['Jennifer_Capriati', '3', '13'] dist: 0.5006912774830213 verified: True dist_halftone: 0.7398806658452306 verified_halftone: False
# ['Jennifer_Capriati', '24', '29'] dist: 0.7465208398699233 verified: False dist_halftone: 0.8206365659378624 verified_halftone: False
# ['Jennifer_Connelly', '1', '4'] dist: 0.49499835912389756 verified: True dist_halftone: 0.589324163003581 verified_halftone: True
# ['Jennifer_Connelly', '3', '4'] dist: 0.45084664357131715 verified: True dist_halftone: 0.536620407999231 verified_halftone: True
# ['Jennifer_Keller', '2', '4'] dist: 0.3802416323961549 verified: True dist_halftone: 0.43512509864346116 verified_halftone: True
# ['Jennifer_Keller', '3', '4'] dist: 0.4980776087938999 verified: True dist_halftone: 0.5256051262531771 verified_halftone: True
# ['Jeong_Se-hyun', '4', '5'] dist: 0.3948799895836347 verified: True dist_halftone: 0.5328343761235038 verified_halftone: True
# ['Jeremy_Shockey', '1', '2'] dist: 0.336462962071832 verified: True dist_halftone: 0.429682440993782 verified_halftone: True
# ['Jesse_Ventura', '1', '3'] dist: 0.4125515832707588 verified: True dist_halftone: 0.424280985517844 verified_halftone: True
# ['Jessica_Lange', '1', '2'] dist: 0.43498625041156647 verified: True dist_halftone: 0.4780418754547903 verified_halftone: True
# ['Jiang_Zemin', '2', '17'] dist: 0.36013121925655106 verified: True dist_halftone: 0.48499664732591763 verified_halftone: True
# ['Jiang_Zemin', '12', '15'] dist: 0.3676448090543025 verified: True dist_halftone: 0.3306703752281426 verified_halftone: True
# ['Jim_Harrick', '1', '2'] dist: 0.44724904508408336 verified: True dist_halftone: 0.6517160080752272 verified_halftone: False
# ['Jimmy_Carter', '1', '9'] dist: 0.2779898789296961 verified: True dist_halftone: 0.3092901814765468 verified_halftone: True
# ['Jimmy_Carter', '4', '8'] dist: 0.44787296900225243 verified: True dist_halftone: 0.48543301845584325 verified_halftone: True
# ['Jimmy_Carter', '8', '9'] dist: 0.29256848790747775 verified: True dist_halftone: 0.28944233257946383 verified_halftone: True
# ['Joe_Mantello', '1', '2'] dist: 0.40896363230169963 verified: True dist_halftone: 0.576483228611835 verified_halftone: True
# ['Joe_Nichols', '1', '3'] dist: 0.43341016729276777 verified: True dist_halftone: 0.42246621142698 verified_halftone: True
# ['Joe_Nichols', '3', '4'] dist: 0.20546664610312748 verified: True dist_halftone: 0.46593671035142253 verified_halftone: True
# ['John_Bolton', '3', '10'] dist: 0.3338426835910828 verified: True dist_halftone: 0.45260174464931957 verified_halftone: True
# ['John_Bolton', '4', '14'] dist: 0.4070494250134148 verified: True dist_halftone: 0.5503581867999797 verified_halftone: True
# ['John_Bolton', '5', '13'] dist: 0.29613116029437553 verified: True dist_halftone: 0.2912722673209012 verified_halftone: True
# ['John_Bolton', '11', '14'] dist: 0.42942557586377633 verified: True dist_halftone: 0.3742395424640966 verified_halftone: True
# ['John_Garamendi', '1', '2'] dist: 0.35986117700542014 verified: True dist_halftone: 0.3961090282819306 verified_halftone: True
# ['John_McCallum', '1', '2'] dist: 0.3731815071103038 verified: True dist_halftone: 0.5687923173776815 verified_halftone: True
# ['John_Negroponte', '4', '17'] dist: 0.48320818492958084 verified: True dist_halftone: 0.5010513865473889 verified_halftone: True
# ['John_Rowland', '1', '2'] dist: 0.4517944358196234 verified: True dist_halftone: 0.49154854110221513 verified_halftone: True
# ['John_Stallworth', '1', '2'] dist: 0.5683079251991279 verified: True dist_halftone: 0.6767575996844103 verified_halftone: False
# ['John_Travolta', '4', '5'] dist: 0.5850901857260077 verified: True dist_halftone: 0.6027083954615476 verified_halftone: False
# ['John_Walsh', '1', '2'] dist: 0.2781797028120287 verified: True dist_halftone: 0.5469793615993264 verified_halftone: True
# ['Johnny_Carson', '1', '2'] dist: 0.3889946887374249 verified: True dist_halftone: 0.5693660831954608 verified_halftone: True
# ['Jorge_Castaneda', '1', '2'] dist: 0.28894173041402915 verified: True dist_halftone: 0.4099869927305196 verified_halftone: True
# ['Jose_Dirceu', '1', '2'] dist: 0.4719326888806206 verified: True dist_halftone: 0.47205233350138026 verified_halftone: True
# ['Joseph_Deiss', '1', '2'] dist: 0.40915874043236766 verified: True dist_halftone: 0.42385188014579345 verified_halftone: True
# ['Judi_Dench', '1', '2'] dist: 0.4775882082295598 verified: True dist_halftone: 0.5109863592200994 verified_halftone: True
# ['Julie_Gerberding', '7', '12'] dist: 0.4194323110994627 verified: True dist_halftone: 0.3981791015432982 verified_halftone: True
# ['Julie_Gerberding', '8', '12'] dist: 0.35698848517103715 verified: True dist_halftone: 0.41534827271423747 verified_halftone: True
# ['Justin_Leonard', '1', '3'] dist: 0.4169638502528846 verified: True dist_halftone: 0.6515662135024411 verified_halftone: False
# ['Justine_Henin', '1', '3'] dist: 0.42601232130656724 verified: True dist_halftone: 0.47514373430796564 verified_halftone: True
# ['Justine_Henin', '2', '3'] dist: 0.3503775360086536 verified: True dist_halftone: 0.36923401534594347 verified_halftone: True
# ['Kamal_Kharrazi', '3', '5'] dist: 0.3966858025656588 verified: True dist_halftone: 0.3930060364900736 verified_halftone: True
# ['Keith_Bogans', '2', '3'] dist: 0.33733238678627664 verified: True dist_halftone: 0.40332157477766317 verified_halftone: True
# ['Kenneth_Evans', '1', '2'] dist: 0.49809861711127845 verified: True dist_halftone: 0.5023144457334007 verified_halftone: True
# ['Kim_Yong-il', '1', '2'] dist: 0.3664965241771096 verified: True dist_halftone: 0.48677226178845573 verified_halftone: True
# ['King_Abdullah_II', '1', '2'] dist: 0.42387512395453353 verified: True dist_halftone: 0.5225842820350933 verified_halftone: True
# ['King_Abdullah_II', '1', '3'] dist: 0.3814475460039727 verified: True dist_halftone: 0.516579812654602 verified_halftone: True
# ['King_Abdullah_II', '1', '4'] dist: 0.40759028878039666 verified: True dist_halftone: 0.45239791224939613 verified_halftone: True
# ['King_Abdullah_II', '2', '3'] dist: 0.46961307986270134 verified: True dist_halftone: 0.5480350066487016 verified_halftone: True
# ['Kjell_Magne_Bondevik', '1', '2'] dist: 0.36840289604259474 verified: True dist_halftone: 0.4752349785035795 verified_halftone: True
# ['Kosuke_Kitajima', '1', '2'] dist: 0.43439957299088844 verified: True dist_halftone: 0.4261764054810879 verified_halftone: True
# ['Kristen_Breitweiser', '1', '2'] dist: 0.2578678167221918 verified: True dist_halftone: 0.4653023095385274 verified_halftone: True
# ['Kristin_Davis', '1', '2'] dist: 0.302962593256911 verified: True dist_halftone: 0.47719789530148093 verified_halftone: True
# ['Kristin_Davis', '2', '3'] dist: 0.437977122798422 verified: True dist_halftone: 0.467529064987899 verified_halftone: True
# ['Kurt_Warner', '1', '5'] dist: 0.5247572883935938 verified: True dist_halftone: 0.5466453610731794 verified_halftone: True
# ['LK_Advani', '1', '2'] dist: 0.4112047850955312 verified: True dist_halftone: 0.46493309275004596 verified_halftone: True
# ['LK_Advani', '1', '3'] dist: 0.4082063385997806 verified: True dist_halftone: 0.5613911719831431 verified_halftone: True
# ['LK_Advani', '2', '3'] dist: 0.5057670512077213 verified: True dist_halftone: 0.5258999293692193 verified_halftone: True
# ['Larry_Coker', '2', '4'] dist: 0.3263626523311747 verified: True dist_halftone: 0.5486153515305278 verified_halftone: True
# ['Latrell_Sprewell', '1', '2'] dist: 0.5942064657802849 verified: True dist_halftone: 0.47620862543450293 verified_halftone: True
# ['Laura_Linney', '1', '3'] dist: 0.5280396306157911 verified: True dist_halftone: 0.5957141334547286 verified_halftone: True
# ['Lauren_Killian', '1', '2'] dist: 0.489162619140103 verified: True dist_halftone: 0.6249079950109117 verified_halftone: False
# ['Laurent_Jalabert', '1', '2'] dist: 0.688886411080799 verified: False dist_halftone: 0.7529556762763405 verified_halftone: False
# ['Leonardo_DiCaprio', '1', '8'] dist: 0.40039907248565143 verified: True dist_halftone: 0.4737950464010963 verified_halftone: True
# ['Leonardo_DiCaprio', '3', '7'] dist: 0.39309796861292273 verified: True dist_halftone: 0.5616799119062139 verified_halftone: True
# ['Leonid_Kuchma', '1', '6'] dist: 0.32494544849127077 verified: True dist_halftone: 0.45138357363514475 verified_halftone: True
# ['Leonid_Kuchma', '2', '3'] dist: 0.33898002359386126 verified: True dist_halftone: 0.4622388896981182 verified_halftone: True
# ['Leonid_Kuchma', '2', '4'] dist: 0.24137878426146078 verified: True dist_halftone: 0.5318208776548584 verified_halftone: True
# ['Leonid_Kuchma', '4', '6'] dist: 0.3378595146972727 verified: True dist_halftone: 0.35929799612848723 verified_halftone: True
# ['Leslie_Moonves', '1', '2'] dist: 0.4763171320507657 verified: True dist_halftone: 0.487994689112229 verified_halftone: True
# ['Leszek_Miller', '2', '3'] dist: 0.5595306872729194 verified: True dist_halftone: 0.612887504391556 verified_halftone: False
# ['Lino_Oviedo', '1', '2'] dist: 0.3494107248122092 verified: True dist_halftone: 0.30938815886402143 verified_halftone: True
# ['Lisa_Raymond', '1', '2'] dist: 0.6877323422124589 verified: False dist_halftone: 0.6353019440637762 verified_halftone: False
# ['Liza_Minnelli', '1', '3'] dist: 0.3763878589712071 verified: True dist_halftone: 0.6358670424692923 verified_halftone: False
# ['Lloyd_Ward', '1', '2'] dist: 0.40581444005910206 verified: True dist_halftone: 0.46191140830111665 verified_halftone: True
# ['Luciano_Pavarotti', '1', '3'] dist: 0.3322438261317001 verified: True dist_halftone: 0.5303574857353706 verified_halftone: True
# ['Lucy_Liu', '2', '4'] dist: 0.5325269788719561 verified: True dist_halftone: 0.6008377334780989 verified_halftone: False
# ['Luis_Figo', '1', '2'] dist: 0.49887807515025623 verified: True dist_halftone: 0.5427392061339508 verified_halftone: True
# ['Luis_Horna', '1', '3'] dist: 0.5019665806283055 verified: True dist_halftone: 0.5818411362087167 verified_halftone: True
# ['Luis_Horna', '2', '5'] dist: 0.5997035051634886 verified: True dist_halftone: 0.5869072560922363 verified_halftone: True
# ['Lynn_Abraham', '1', '2'] dist: 0.5673878454737197 verified: True dist_halftone: 0.6026019079559234 verified_halftone: False
# ['Mack_Brown', '1', '2'] dist: 0.4584078236105032 verified: True dist_halftone: 0.5926901095826307 verified_halftone: True
# ['Mahmoud_Abbas', '19', '26'] dist: 0.2119380228696477 verified: True dist_halftone: 0.5267187808857612 verified_halftone: True
# ['Marcelo_Rios', '1', '4'] dist: 0.5281914172481272 verified: True dist_halftone: 0.6561579715443954 verified_halftone: False
# ['Marcelo_Rios', '2', '4'] dist: 0.3709794796453706 verified: True dist_halftone: 0.534502103674417 verified_halftone: True
# ['Marcelo_Rios', '4', '5'] dist: 0.3068253516210185 verified: True dist_halftone: 0.3851567603507651 verified_halftone: True
# ['Marieta_Chrousala', '1', '2'] dist: 0.4224525218774436 verified: True dist_halftone: 0.5536077820592445 verified_halftone: True
# ['Marieta_Chrousala', '1', '3'] dist: 0.41341489940957254 verified: True dist_halftone: 0.5337969266340532 verified_halftone: True
# ['Mario_Cipollini', '1', '2'] dist: 0.2914153685241708 verified: True dist_halftone: 0.5035464341328969 verified_halftone: True
# ['Mark_Dacey', '1', '2'] dist: 0.3873447856065037 verified: True dist_halftone: 0.49592743611446016 verified_halftone: True
# ['Mark_Richt', '1', '3'] dist: 0.4678893505790279 verified: True dist_halftone: 0.6066057717537797 verified_halftone: False
# ['Mark_Richt', '2', '3'] dist: 0.6505560548233745 verified: False dist_halftone: 0.638317772474061 verified_halftone: False
# ['Martha_Burk', '2', '4'] dist: 0.5101178459030979 verified: True dist_halftone: 0.44275380024776945 verified_halftone: True
# ['Martha_Stewart', '1', '2'] dist: 0.5242998679190927 verified: True dist_halftone: 0.5501779944505555 verified_halftone: True
# ['Martha_Stewart', '2', '5'] dist: 0.7557427515001571 verified: False dist_halftone: 0.407138430505367 verified_halftone: True
# ['Martha_Stewart', '3', '5'] dist: 0.6506589334940235 verified: False dist_halftone: 0.5948395078497217 verified_halftone: True
# ['Martin_Cauchon', '1', '2'] dist: 0.25060420156672825 verified: True dist_halftone: 0.3999045048416284 verified_halftone: True
# ['Martin_Sheen', '1', '2'] dist: 0.37301696371350856 verified: True dist_halftone: 0.5026679814864815 verified_halftone: True
# ['Mary_Landrieu', '1', '3'] dist: 0.5074492245395872 verified: True dist_halftone: 0.6054649019783416 verified_halftone: False
# ['Masum_Turker', '1', '2'] dist: 0.27825263968201885 verified: True dist_halftone: 0.4138850673874883 verified_halftone: True
# ['Masum_Turker', '1', '3'] dist: 0.3331139511937452 verified: True dist_halftone: 0.455407096453945 verified_halftone: True
# ['Matt_Doherty', '1', '2'] dist: 0.6855719807810606 verified: False dist_halftone: 0.5913624889063415 verified_halftone: True
# ['Matt_Doherty', '1', '3'] dist: 0.6165845808749016 verified: False dist_halftone: 0.47293993367891934 verified_halftone: True
# ['Matthew_Broderick', '1', '4'] dist: 0.4895546330352997 verified: True dist_halftone: 0.5121821226094161 verified_halftone: True
# ['Matthew_Broderick', '2', '3'] dist: 0.47320557305572575 verified: True dist_halftone: 0.4646283180494584 verified_halftone: True
# ['Matthew_Broderick', '3', '4'] dist: 0.422031145386494 verified: True dist_halftone: 0.4614904012241432 verified_halftone: True
# ['Melissa_Etheridge', '1', '2'] dist: 0.3401511604905411 verified: True dist_halftone: 0.777810717570322 verified_halftone: False
# ['Michael_Jackson', '2', '8'] dist: 0.5165636106414238 verified: True dist_halftone: 0.7811338460211013 verified_halftone: False
# ['Michael_Phelps', '1', '3'] dist: 0.46645718987734663 verified: True dist_halftone: 0.5125572653776459 verified_halftone: True
# ['Michael_Sullivan', '1', '2'] dist: 0.4662534517296674 verified: True dist_halftone: 0.5433387432375445 verified_halftone: True
# ['Michel_Duclos', '1', '2'] dist: 0.3787144049035607 verified: True dist_halftone: 0.5844934492353382 verified_halftone: True
# ['Michelle_Yeoh', '3', '4'] dist: 0.5058431772229692 verified: True dist_halftone: 0.5717327958522219 verified_halftone: True
# ['Miguel_Contreras', '1', '2'] dist: 0.3056041040749315 verified: True dist_halftone: 0.5606167050722745 verified_halftone: True
# ['Mike_Price', '1', '2'] dist: 0.5055623119912118 verified: True dist_halftone: 0.4025380142179343 verified_halftone: True
# ['Mikhail_Youzhny', '1', '2'] dist: 0.46458180526463927 verified: True dist_halftone: 0.6196190460275829 verified_halftone: False
# ['Mikhail_Youzhny', '1', '3'] dist: 0.45501901178609583 verified: True dist_halftone: 0.5702359734588834 verified_halftone: True
# ['Mikhail_Youzhny', '2', '3'] dist: 0.468168228393456 verified: True dist_halftone: 0.5489970336986513 verified_halftone: True
# ['Mikulas_Dzurinda', '1', '2'] dist: 0.40266712172742264 verified: True dist_halftone: 0.5537346733102124 verified_halftone: True
# ['Mireya_Moscoso', '1', '3'] dist: 0.6393544882327168 verified: False dist_halftone: 0.5572461036244293 verified_halftone: True
# ['Mireya_Moscoso', '2', '3'] dist: 0.2673016110972199 verified: True dist_halftone: 0.45058922132618584 verified_halftone: True
# ['Mohamed_ElBaradei', '3', '6'] dist: 0.4619957082331173 verified: True dist_halftone: 0.6021680929721371 verified_halftone: False
# ['Mohamed_ElBaradei', '4', '5'] dist: 0.3071717491954777 verified: True dist_halftone: 0.5019792427613241 verified_halftone: True
# ['Mohamed_ElBaradei', '5', '8'] dist: 0.5114194723969295 verified: True dist_halftone: 0.660063505398106 verified_halftone: False
# ['Monica_Lewinsky', '2', '3'] dist: 0.5610124911347936 verified: True dist_halftone: 0.6952919925462404 verified_halftone: False
# ['Muhammad_Ali', '4', '7'] dist: 0.5860629479474477 verified: True dist_halftone: 0.42967026116119134 verified_halftone: True
# ['Muhammad_Ali', '6', '9'] dist: 0.3984033031019829 verified: True dist_halftone: 0.5823894726562977 verified_halftone: True
# ['Nancy_Pelosi', '2', '5'] dist: 0.40011421590812346 verified: True dist_halftone: 0.4697824925641142 verified_halftone: True
# ['Nancy_Pelosi', '6', '13'] dist: 0.830788664378713 verified: False dist_halftone: 0.6648237317424287 verified_halftone: False
# ['Nancy_Pelosi', '13', '14'] dist: 0.7939884979703066 verified: False dist_halftone: 0.5901938893880403 verified_halftone: True
# ['Naomi_Campbell', '1', '2'] dist: 0.4138322768107023 verified: True dist_halftone: 0.45548987454191153 verified_halftone: True
# ['Naoto_Kan', '2', '3'] dist: 0.16464259465502099 verified: True dist_halftone: 0.48564065871842993 verified_halftone: True
# ['Nasser_al-Kidwa', '1', '2'] dist: 0.41127956092576096 verified: True dist_halftone: 0.48199722907871284 verified_halftone: True
# ['Nastassia_Kinski', '1', '2'] dist: 0.3793723676447221 verified: True dist_halftone: 0.5109473078661648 verified_halftone: True
# ['Natalie_Coughlin', '1', '2'] dist: 0.43826203228832117 verified: True dist_halftone: 0.6515273078590065 verified_halftone: False
# ['Natalie_Coughlin', '3', '5'] dist: 0.672645471640332 verified: False dist_halftone: 0.5845891540471947 verified_halftone: True
# ['Natalie_Maines', '2', '4'] dist: 0.4824335644657022 verified: True dist_halftone: 0.8174652190622004 verified_halftone: False
# ['Nicanor_Duarte_Frutos', '8', '10'] dist: 0.4263125443882207 verified: True dist_halftone: 0.5745345577542165 verified_halftone: True
# ['Noah_Wyle', '1', '2'] dist: 0.3827403138777902 verified: True dist_halftone: 0.49332902475991663 verified_halftone: True
# ['Norm_Coleman', '2', '7'] dist: 0.31137466181226875 verified: True dist_halftone: 0.41054180944605784 verified_halftone: True
# ['Orrin_Hatch', '1', '2'] dist: 0.35015752200624384 verified: True dist_halftone: 0.44781616789639594 verified_halftone: True
# ['Osama_bin_Laden', '2', '4'] dist: 0.3558241482682954 verified: True dist_halftone: 0.5083682128726176 verified_halftone: True
# ['Owen_Wilson', '1', '2'] dist: 0.5758453292478878 verified: True dist_halftone: 0.639343401453966 verified_halftone: False
# ['Ozzy_Osbourne', '1', '2'] dist: 0.5276120449321896 verified: True dist_halftone: 0.5742770804968902 verified_halftone: True
# ['Ozzy_Osbourne', '2', '3'] dist: 0.4277249849199974 verified: True dist_halftone: 0.594029403160595 verified_halftone: True
# ['Padraig_Harrington', '1', '3'] dist: 0.4629463051562676 verified: True dist_halftone: 0.6035555340682307 verified_halftone: False
# ['Paris_Hilton', '1', '2'] dist: 0.4087116773135504 verified: True dist_halftone: 0.7230275777879449 verified_halftone: False
# ['Patrick_Leahy', '1', '2'] dist: 0.4133135409871027 verified: True dist_halftone: 0.5319079490375307 verified_halftone: True
# ['Patti_Labelle', '1', '2'] dist: 0.356073349652012 verified: True dist_halftone: 0.5761596975535007 verified_halftone: True
# ['Patti_Labelle', '2', '3'] dist: 0.40516354267179217 verified: True dist_halftone: 0.5955787382892994 verified_halftone: True
# ['Patty_Schnyder', '1', '3'] dist: 0.6131666457707596 verified: False dist_halftone: 0.556130731700555 verified_halftone: True
# ['Patty_Schnyder', '1', '4'] dist: 0.6534305934079362 verified: False dist_halftone: 0.6202740121516456 verified_halftone: False
# ['Paul-Henri_Mathieu', '1', '2'] dist: 0.526255357851306 verified: True dist_halftone: 0.5698196310129818 verified_halftone: True
# ...
# ['Laszlo_Kovacs', '1', 'Michael_Arif', '1'] dist: 0.37650121589763935 verified: True dist_halftone: 0.4355272441807057 verified_halftone: True
# ['Laura_Elena_Harring', '1', 'Rowan_Williams', '1'] dist: 0.8374164339050079 verified: False dist_halftone: 0.825771001832983 verified_halftone: False
# ['Laurel_Clark', '1', 'Rahul_Dravid', '1'] dist: 0.6154761777883777 verified: False dist_halftone: 0.6673697609146866 verified_halftone: False
# ['Lawrence_Di_Rita', '1', 'Tim_Allen', '2'] dist: 0.5796297123932848 verified: True dist_halftone: 0.6576795001159583 verified_halftone: False
# ['Lawrence_Roberts', '1', 'Malik_Mahmud', '1'] dist: 0.6534433503833535 verified: False dist_halftone: 0.6716381897876293 verified_halftone: False
# ['Lea_Fastow', '1', 'Todd_Parrott', '1'] dist: 0.5036580128829705 verified: True dist_halftone: 0.6232195768899464 verified_halftone: False
# ['Lee_Baca', '1', 'Pat_Summerall', '1'] dist: 0.6884653014396317 verified: False dist_halftone: 0.6279646929726529 verified_halftone: False
# ['Leisel_Jones', '1', 'Steven_Hatfill', '1'] dist: 0.8478541325355425 verified: False dist_halftone: 0.661973950422005 verified_halftone: False
# ['Lena_Katina', '1', 'Queen_Noor', '1'] dist: 0.5744119334284479 verified: True dist_halftone: 0.6713904128721492 verified_halftone: False
# ['Leonard_Glick', '1', 'Terrence_Trammell', '1'] dist: 0.613283857651105 verified: False dist_halftone: 0.7268961234683405 verified_halftone: False
# ['Leonard_Schrank', '1', 'Ozzy_Osbourne', '1'] dist: 0.7127450731952919 verified: False dist_halftone: 0.9768400657628136 verified_halftone: False
# ['Leslie_Wiser_Jr', '1', 'Mireya_Moscoso', '1'] dist: 0.7104283107607011 verified: False dist_halftone: 0.688407837418446 verified_halftone: False
# ['Lisa_Murkowski', '1', 'Svetlana_Belousova', '1'] dist: 0.628442765187937 verified: False dist_halftone: 0.37023971979257075 verified_halftone: True
# ['Lisa_Raymond', '2', 'Robert_Redford', '7'] dist: 0.8064017256755917 verified: False dist_halftone: 0.7767171518064493 verified_halftone: False
# ['Ludwig_Ovalle', '1', 'Mauricio_Macri', '1'] dist: 0.6268837786288476 verified: False dist_halftone: 0.5164373050091017 verified_halftone: True
# ['Luis_Pujols', '1', 'Rohman_al-Ghozi', '1'] dist: 0.6887789068047944 verified: False dist_halftone: 0.5522901683452722 verified_halftone: True
# ['Makhdoom_Amin_Fahim', '1', 'Tang_Jiaxuan', '5'] dist: 0.41263517884310175 verified: True dist_halftone: 0.5102832659039164 verified_halftone: True
# ['Malcolm_Wild', '1', 'Owen_Wilson', '2'] dist: 0.6950283183261587 verified: False dist_halftone: 0.6530644017163443 verified_halftone: False
# ['Mamdouh_Habib', '1', 'Polona_Bas', '1'] dist: 0.929203550129599 verified: False dist_halftone: 0.8665465771557563 verified_halftone: False
# ['Manijeh_Hekmat', '1', 'Richard_Carl', '1'] dist: 0.590608164102414 verified: True dist_halftone: 0.5108814770007624 verified_halftone: True
# ['Manijeh_Hekmat', '1', 'Se_Hyuk_Joo', '1'] dist: 0.6163239360096822 verified: False dist_halftone: 0.592838219919242 verified_halftone: True
# ['Marc_Anthony', '1', 'Vince_Vaughan', '1'] dist: 0.5554073641537226 verified: True dist_halftone: 0.4508099748460654 verified_halftone: True
# ['Margie_Puente', '1', 'Rafiq_Hariri', '1'] dist: 0.5677061437001031 verified: True dist_halftone: 0.5645030607954421 verified_halftone: True
# ['Maria_Callas', '1', 'Melchor_Cob_Castro', '1'] dist: 0.6721191301478362 verified: False dist_halftone: 0.7484164123982029 verified_halftone: False
# ['Mario_Lemieux', '1', 'Pedro_Solbes', '4'] dist: 0.6146050122976806 verified: False dist_halftone: 0.6261561985071833 verified_halftone: False
# ['Marissa_Jaret_Winokur', '1', 'Vincent_Sombrotto', '1'] dist: 0.8396825094225913 verified: False dist_halftone: 0.8127120769418887 verified_halftone: False
# ['Mark_Dacey', '2', 'Russ_Ortiz', '1'] dist: 0.56648845045471 verified: True dist_halftone: 0.6258294957412514 verified_halftone: False
# ['Mark_Martin', '1', 'Vladimir_Spidla', '2'] dist: 0.4966334483144061 verified: True dist_halftone: 0.6951222079452369 verified_halftone: False
# ['Mark_Mishkin', '1', 'Nick_Reilly', '1'] dist: 0.5750154663474873 verified: True dist_halftone: 0.682028790926263 verified_halftone: False
# ['Mark_Mishkin', '1', 'Shawn_Marion', '1'] dist: 0.7132758717698744 verified: False dist_halftone: 0.5861261891642694 verified_halftone: True
# ['Marricia_Tate', '1', 'Rita_Moreno', '2'] dist: 0.8525803697005907 verified: False dist_halftone: 0.8623637302935792 verified_halftone: False
# ['Mary_Landrieu', '1', 'Robert_Gordon_Card', '1'] dist: 0.8165886723762452 verified: False dist_halftone: 0.6194348771646131 verified_halftone: False
# ['Maryn_McKenna', '1', 'Shawn_Marion', '1'] dist: 0.8053736670504463 verified: False dist_halftone: 0.715298499199562 verified_halftone: False
# ['Maryn_McKenna', '1', 'Tim_Pawlenty', '1'] dist: 0.6390649901752583 verified: False dist_halftone: 0.6466646668041853 verified_halftone: False
# ['Masum_Turker', '1', 'Norman_Mineta', '1'] dist: 0.37750589177083776 verified: True dist_halftone: 0.45486413209855137 verified_halftone: True
# ['Matt_Dillon', '1', 'Regina_Ip', '1'] dist: 0.7497735512837906 verified: False dist_halftone: 0.585161741924543 verified_halftone: True
# ['Matthias_Sammer', '1', 'Robbie_Naish', '1'] dist: 0.5583375343481594 verified: True dist_halftone: 0.6164956194515628 verified_halftone: False
# ['Melissa_Etheridge', '2', 'Teri_Files', '1'] dist: 0.5196901728766352 verified: True dist_halftone: 0.6039556059378981 verified_halftone: False
# ['Michael_J_Sheehan', '1', 'Michael_Smith_Foster', '1'] dist: 0.5275312231580516 verified: True dist_halftone: 0.6734041075566798 verified_halftone: False
# ['Michael_Linscott', '1', 'Robin_Tunney', '1'] dist: 0.8029604753432449 verified: False dist_halftone: 0.6751876677616246 verified_halftone: False
# ['Michael_Phelps', '5', 'Pat_Burns', '2'] dist: 0.6548677981158436 verified: False dist_halftone: 0.6639714697690818 verified_halftone: False
# ['Michael_Sheehan', '1', 'Vincent_Cianci_Jr', '1'] dist: 0.47280534521684825 verified: True dist_halftone: 0.8355495554767348 verified_halftone: False
# ['Michael_Smith_Foster', '1', 'Rupert_Murdoch', '1'] dist: 0.5308611233438811 verified: True dist_halftone: 0.5562571526839012 verified_halftone: True
# ['Michelle_Yeoh', '5', 'Shoshannah_Stern', '1'] dist: 0.7384322637020654 verified: False dist_halftone: 0.6987005912568987 verified_halftone: False
# ['Miguel_Aldana_Ibarra', '1', 'Mikhail_Gorbachev', '1'] dist: 0.3094313256559907 verified: True dist_halftone: 0.5862904109194236 verified_halftone: True
# ['Miguel_Jimenez', '1', 'Paris_Hilton', '1'] dist: 0.9069802449578437 verified: False dist_halftone: 1.0738775172366426 verified_halftone: False
# ['Mike_Helton', '2', 'Reggie_Lewis', '1'] dist: 0.72252288679572 verified: False dist_halftone: 0.6515164717197158 verified_halftone: False
# ['Mike_Leach', '1', 'Thomas_Haeggstroem', '1'] dist: 0.5322781987455123 verified: True dist_halftone: 0.6468489516364695 verified_halftone: False
# ['Mike_Maroth', '1', 'Stefan_Holm', '1'] dist: 0.6056420226917764 verified: False dist_halftone: 0.6442343876247177 verified_halftone: False
# ['Mike_Slive', '1', 'Paul_Sarbanes', '3'] dist: 0.36109451486550737 verified: True dist_halftone: 0.5596107045206168 verified_halftone: True
# ['Mikhail_Youzhny', '2', 'Vince_Dooley', '1'] dist: 0.6182842596355275 verified: False dist_halftone: 0.6907512214315054 verified_halftone: False
# ['Mikulas_Dzurinda', '2', 'Shirley_Jones', '1'] dist: 0.799539004383667 verified: False dist_halftone: 0.8544824808948539 verified_halftone: False
# ['Miles_Stewart', '1', 'Yasushi_Akashi', '1'] dist: 0.5150272331040707 verified: True dist_halftone: 0.703516274191326 verified_halftone: False
# ['Mirela_Manjani', '1', 'Robert_Woody_Johnson', '1'] dist: 0.8482322341679548 verified: False dist_halftone: 0.9048721010078677 verified_halftone: False
# ['Mitchell_McLaughlin', '1', 'Timothy_Goebel', '1'] dist: 0.8443313166317301 verified: False dist_halftone: 0.493427116430843 verified_halftone: True
# ['Mohammed_Baqir_al-Hakim', '3', 'Neil_Goldman', '1'] dist: 0.7257866253290904 verified: False dist_halftone: 0.5710293663779952 verified_halftone: True
# ['Mona_Ayoub', '1', 'Todd_Parrott', '1'] dist: 0.8438907648642342 verified: False dist_halftone: 0.9700080023451557 verified_halftone: False
# ['Mufti_Mohammad_Syed', '1', 'Ralf_Schumacher', '4'] dist: 0.7005313063703746 verified: False dist_halftone: 0.6235164364830572 verified_halftone: False
# ['Nathalie_Gagnon', '1', 'Rupert_Grint', '2'] dist: 0.7176461269504866 verified: False dist_halftone: 0.6912875076946363 verified_halftone: False
# ['Neil_Goldman', '1', 'Niall_Connolly', '1'] dist: 0.6483662416535951 verified: False dist_halftone: 0.6821946615787102 verified_halftone: False
# ['Nick_Reilly', '1', 'Tassos_Papadopoulos', '1'] dist: 0.5458255926276572 verified: True dist_halftone: 0.7311378816600191 verified_halftone: False
# ['Nicolas_Sarkozy', '1', 'Shanna_Zolman', '1'] dist: 0.5999191683350554 verified: True dist_halftone: 0.5625926414154678 verified_halftone: True
# ['Norm_Coleman', '2', 'Osmond_Smith', '1'] dist: 0.5204821993328236 verified: True dist_halftone: 0.5333918391033402 verified_halftone: True
# ['Norman_Mailer', '1', 'Steven_Curtis_Chapman', '1'] dist: 0.5468811943955013 verified: True dist_halftone: 0.46182981383041133 verified_halftone: True
# ['Oliver_Neuville', '1', 'Shawn_Marion', '1'] dist: 0.7474418031241272 verified: False dist_halftone: 0.6775267758890046 verified_halftone: False
# ['Park_Jie-won', '1', 'Steve_Patterson', '1'] dist: 0.42115256176925164 verified: True dist_halftone: 0.4094187495804479 verified_halftone: True
# ['Patty_Sheehan', '1', 'William_Nessen', '1'] dist: 0.7305098901238081 verified: False dist_halftone: 0.47978448075713254 verified_halftone: True
# ['Paul_Hogan', '1', 'Thomas_Watjen', '1'] dist: 0.6053733973032266 verified: False dist_halftone: 0.5243705198090298 verified_halftone: True
# ['Paul_Hogan', '1', 'William_Martin', '1'] dist: 0.5966305312332473 verified: True dist_halftone: 0.5789704774701364 verified_halftone: True
# ['Paul_Kariya', '1', 'Shannon_OBrien', '2'] dist: 0.5657601705814261 verified: True dist_halftone: 0.6544574979603599 verified_halftone: False
# ['Paul_Martin', '1', 'Stephanie_Cohen_Aloro', '1'] dist: 0.45773089954530227 verified: True dist_halftone: 0.5716359730923286 verified_halftone: True
# ['Paul_Michael_Daniels', '1', 'Simon_Chalk', '1'] dist: 0.5227741531375945 verified: True dist_halftone: 0.6960561593648071 verified_halftone: False
# ['Paul_Schrader', '1', 'Teri_Files', '1'] dist: 0.6303367944351089 verified: False dist_halftone: 0.7047741331291959 verified_halftone: False
# ['Paula_Prentiss', '1', 'Thomas_Mesereau_Jr', '1'] dist: 0.5792566934814137 verified: True dist_halftone: 0.6435287245020055 verified_halftone: False
# ['Pedro_Martinez', '1', 'Stephen_Glassroth', '1'] dist: 0.5440404404955107 verified: True dist_halftone: 0.47655848823160946 verified_halftone: True
# ['Peter_Fitzgerald', '1', 'Zelma_Novelo', '1'] dist: 0.6085666641131027 verified: False dist_halftone: 0.5124406593487594 verified_halftone: True
# ['Phil_Jackson', '1', 'Richard_Penniman', '1'] dist: 0.722781113339348 verified: False dist_halftone: 0.5412172825463376 verified_halftone: True
# ['Phillipe_Comtois', '1', 'Richard_Carl', '1'] dist: 0.7369217691349031 verified: False dist_halftone: 0.7199582190131097 verified_halftone: False
# ['Pierre_Boulanger', '1', 'Shania_Twain', '1'] dist: 0.7778960419017749 verified: False dist_halftone: 0.5334624137682301 verified_halftone: True
# ['Princess_Diana', '1', 'Steffi_Graf', '2'] dist: 0.6141416303288988 verified: False dist_halftone: 0.6009345491221305 verified_halftone: False
# ['Priscilla_Presley', '1', 'Sergey_Lavrov', '5'] dist: 0.6974925445064765 verified: False dist_halftone: 0.798608468331285 verified_halftone: False
# ['Priscilla_Presley', '1', 'Victoria_Beckham', '3'] dist: 0.5316389046133189 verified: True dist_halftone: 0.6070786948155177 verified_halftone: False
# ['Richard_Butler', '1', 'Victoria_Beckham', '1'] dist: 0.7926950096706026 verified: False dist_halftone: 0.8824187732161456 verified_halftone: False
# ['Richard_Pennington', '1', 'Stacy_Nelson', '1'] dist: 0.6433433989140102 verified: False dist_halftone: 0.9651356908193833 verified_halftone: False
# ['Rick_Caruso', '1', 'Steve_Wariner', '1'] dist: 0.4696865725730604 verified: True dist_halftone: 0.6137893758200289 verified_halftone: False
# ['Rick_Perry', '6', 'Svetlana_Koroleva', '1'] dist: 0.6634086679449545 verified: False dist_halftone: 0.6856167537041683 verified_halftone: False
# ['Ricky_Cottrill', '1', 'Sananda_Maitreya', '1'] dist: 0.6239287648939826 verified: False dist_halftone: 0.6874150676287976 verified_halftone: False
# ['Robert_Flodquist', '1', 'Winona_Ryder', '11'] dist: 0.6609541707564655 verified: False dist_halftone: 0.667762577641103 verified_halftone: False
# ['Rod_Stewart', '1', 'Tom_Scully', '1'] dist: 0.5759031091904412 verified: True dist_halftone: 0.563695713465693 verified_halftone: True
# ['Rod_Stewart', '3', 'Se_Hyuk_Joo', '1'] dist: 0.7260859980731079 verified: False dist_halftone: 0.710983042917611 verified_halftone: False
# ['Rod_Thorn', '1', 'Yves_Brodeur', '1'] dist: 0.5745788694370312 verified: True dist_halftone: 0.5587093416466832 verified_halftone: True
# ['Ron_Howard', '1', 'Tim_Pawlenty', '1'] dist: 0.5348066608464921 verified: True dist_halftone: 0.5968329547702665 verified_halftone: True
# ['Ronaldo_Luis_Nazario_de_Lima', '1', 'Samuel_Waksal', '2'] dist: 0.7157272256550358 verified: False dist_halftone: 0.7543737994547879 verified_halftone: False
# ['Sami_Al-Arian', '1', 'Tommy_Lasorda', '1'] dist: 0.53845063954316 verified: True dist_halftone: 0.5057901843012184 verified_halftone: True
# ['Sarah_Canale', '1', 'Steven_Curtis_Chapman', '1'] dist: 0.6860352964551968 verified: False dist_halftone: 0.6520747193362018 verified_halftone: False
# ['Sasha_Cohen', '1', 'Valery_Giscard_dEstaing', '5'] dist: 0.74132855534238 verified: False dist_halftone: 0.8068851806578679 verified_halftone: False
# ['Scott_Dalton', '1', 'Tamara_Mowry', '1'] dist: 0.7749223523036569 verified: False dist_halftone: 1.076683745228687 verified_halftone: False
# ['Sergio_Castellitto', '1', 'Steve_Lavin', '5'] dist: 0.5866808771405537 verified: True dist_halftone: 0.6008899714165389 verified_halftone: False
# ['Seth_Gorney', '1', 'Wilton_Gregory', '1'] dist: 0.7045036149847658 verified: False dist_halftone: 0.7785032766925595 verified_halftone: False
# ['Shane_Mosley', '1', 'Stacey_Dales-Schuman', '1'] dist: 0.5261386125659399 verified: True dist_halftone: 0.6344554994218263 verified_halftone: False
# ['Sheila_Taormina', '1', 'Stephan_Eberharter', '1'] dist: 0.5127272804690004 verified: True dist_halftone: 0.5026444987345765 verified_halftone: True
# ['Stefano_Gabbana', '1', 'Tang_Jiaxuan', '3'] dist: 0.6641190613170763 verified: False dist_halftone: 0.7093997842812122 verified_halftone: False
# ['Steve_Wariner', '1', 'Toshi_Izawa', '1'] dist: 0.5460678516808684 verified: True dist_halftone: 0.6394459439526977 verified_halftone: False
# ['Steve_Zahn', '1', 'Tab_Baldwin', '1'] dist: 0.6364076869007932 verified: False dist_halftone: 0.6905724926268473 verified_halftone: False
# ['Susan_Whelan', '1', 'Wolfgang_Schneiderhan', '1'] dist: 0.5225832682744588 verified: True dist_halftone: 0.5219766483283366 verified_halftone: True
# ['Takeo_Fukui', '1', 'Will_Ofenheusle', '1'] dist: 0.5808965999795007 verified: True dist_halftone: 0.508417960613549 verified_halftone: True
# ['Tamara_Mowry', '1', 'Zach_Parise', '1'] dist: 0.6905286735857411 verified: False dist_halftone: 0.5582073328913413 verified_halftone: True
# ['Tatiana_Kennedy_Schlossberg', '1', 'Thomas_Watjen', '1'] dist: 0.6952375443356336 verified: False dist_halftone: 0.6991435532894511 verified_halftone: False
# ['Todd_Petit', '1', 'Vicente_Fernandez', '3'] dist: 0.6442472760182283 verified: False dist_halftone: 0.7710345680285909 verified_halftone: False
